# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# mambajs 0.21.1
#
# Process pip requirements ...
# Cannot install 'pandas' from PyPI because it is a binary built package that is not compatible with WASM environments. To resolve this issue, you can: 1) Try to install it from emscripten-forge instead: "!mamba install pandas" 2) If that doesn't work, it's probably that the package was not made WASM-compatible on emscripten-forge. You can either request or contribute a new recipe for that package in https://github.com/emscripten-forge/recipes

# %%
# !mamba install pandas
# Out:
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.4947000000476836 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.3    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.2   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge

# %%
import pandas as pd

# %%
help ("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _tokenize           heapq               re
# PIL                 _tracemalloc        hmac                reprlib
# __future__          _typing             html                rlcompleter
# __hello__           _warnings           http                runpy
# __phello__          _weakref            imaplib             sched
# _abc                _weakrefset         importlib           scipy
# _aix_support        _zoneinfo           inspect             secrets
# _android_support    abc                 io                  select
# _ast                antigravity         ipaddress           selectors
# _asyncio            argparse            ipyleaflet          shelve
# _bisect             array               ipywidgets          shlex
# _blake2             ast                 itertools           shutil
# _bz2                asttokens           jinja2              signal
# _codecs             asyncio             json                site
# _codecs_cn          atexit              jupyter_leaflet     six
# _codecs_hk          backcall            jupyterlab_widgets  smtplib
# _codecs_iso2022     base64              keyword             socket
# _codecs_jp          bdb                 kiwisolver          socketserver
# _codecs_kr          binascii            linecache           sqlite3
# _codecs_tw          bisect              locale              sre_compile
# _collections        branca              logging             sre_constants
# _collections_abc    builtins            lzma                sre_parse
# _colorize           bz2                 mailbox             ssl
# _compat_pickle      cProfile            markupsafe          stack_data
# _compression        calendar            marshal             stat
# _contextvars        cmath               math                statistics
# _csv                cmd                 matplotlib          string
# _ctypes             code                matplotlib_inline   stringprep
# _datetime           codecs              mimetypes           struct
# _decimal            codeop              mmap                subprocess
# _elementtree        collections         modulefinder        symtable
# _functools          colorsys            multiprocessing     sys
# _heapq              comm                netrc               sysconfig
# _imp                compileall          ntpath              tabnanny
# _io                 concurrent          nturl2path          tarfile
# _ios_support        configparser        numbers             tempfile
# _json               contextlib          numpy               textwrap
# _locale             contextvars         opcode              this
# _lsprof             contourpy           operator            threading
# _lzma               copy                optparse            time
# _markupbase         copyreg             os                  timeit
# _md5                csv                 packaging           tkinter
# _multibytecodec     ctypes              pandas              token
# _opcode             curses              pathlib             tokenize
# _opcode_metadata    cycler              pdb                 tomllib
# _operator           dataclasses         pexpect             trace
# _osx_support        datetime            pickle              traceback
# _pickle             dateutil            pickleshare         tracemalloc
# _posixsubprocess    dbm                 pickletools         traitlets
# _py_abc             decimal             pkgutil             traittypes
# _pydatetime         decorator           platform            tty
# _pydecimal          difflib             plistlib            turtle
# _pyio               dis                 poplib              turtledemo
# _pylong             doctest             posix               types
# _pyrepl             email               posixpath           typing
# _queue              encodings           pprint              typing_extensions
# _random             enum                profile             tzdata
# _sha1               errno               prompt_toolkit      unicodedata
# _sha2               executing           pstats              unittest
# _sha3               faulthandler        pty                 urllib
# _signal             fcntl               ptyprocess          uuid
# _sitebuiltins       filecmp             pure_eval           venv
# _socket             fileinput           py_compile          warnings
# _sqlite3            fnmatch             pyclbr              wave
# _sre                fontTools           pydoc               wcwidth
# _ssl                fractions           pydoc_data          weakref
# _stat               ftplib              pyexpat             webbrowser
# _statistics         functools           pygments            wsgiref
# _string             gc                  pyjs                xeus_python_shell
# _strptime           genericpath         pyjs_core           xml
# _struct             getopt              pylab               xmlrpc
# _suggestions        getpass             pyodide_http        xyzservices
# _symtable           gettext             pyparsing           zipapp
# _sysconfig          glob                pytz                zipfile
# _sysconfigdata__emscripten_wasm32-emscripten graphlib            queue               zipimport
# _thread             gzip                quopri              zlib
# _threading_local    hashlib             random              zoneinfo
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
pd
# Out:
# <module 'pandas' from '/lib/python3.13/site-packages/pandas/__init__.py'>

# %%
pd.read_csv("/data/moradores.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.read_csv("/data/moradores.csv")
#
# NameError: name 'pd' is not defined

# %%
pandas.read_csv("data/moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pandas.read_csv("data/moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
#
# NameError: name 'pandas' is not defined

# %%
pandas=pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pandas=pd
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

moradores = pd.read_csv("moradores_parcial.csv", sep=";", decimal=",", encoding="utf-8-sig")
print(moradores.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       3 moradores = pd.read_csv("moradores_parcial.csv", sep=";", decimal=",", encoding="utf-8-sig")
#       4 print(moradores.head())
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !mamba install pandas
# Out:
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.080700000047684 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.3    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.2   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge

# %%
import pandas as pd

moradores = pd.read_csv("data/moradores.csv", sep=";", decimal=",")
print(moradores.head())
# Out:
# /tmp/xpython_42/773903904.py:3: DtypeWarning: Columns (0: E03_1_1, 1: E03_2_1) have mixed types. Specify dtype option on import or set low_memory=False.
#   moradores = pd.read_csv("data/moradores.csv", sep=";", decimal=",")
#    A01nficha  A01uf  localidade  setor_distrito morador_id  index  \
# 0          1     53        5330              35    00001-1      1
# 1          2     53        5320              24    00002-1      1
# 2          2     53        5320              24    00002-2      2
# 3          2     53        5320              24    00002-3      3
# 4          2     53        5320              24    00002-4      4
#
#    idade_calculada       E02_1  E02_2  E02_3  ...  I22_2_r    I23 renda_ind  \
# 0               49       99999  99999     49  ...      0.0     50         0
# 1               35  1988-10-17  99999  99999  ...  99999.0      6     99999
# 2               41  1982-08-28  99999  99999  ...  99999.0      6     99999
# 3                5  2019-01-04  99999  99999  ...  99999.0  99999         0
# 4                3  2020-09-25  99999  99999  ...  99999.0  99999         0
#
#    renda_ind_r infla_ipcadf  id_genero  orientacao_sx lgbtqiam  escolaridade  \
# 0          0.0     0.989672          1              2        2             5
# 1      99999.0     0.982196          1              2        2             7
# 2      99999.0     0.982196          1              2        2             7
# 3          0.0     0.982196      99999          99999    99999             1
# 4          0.0     0.982196      99999          99999    99999             1
#
#      peso_mor
# 0   78.620213
# 1  148.818895
# 2  212.895183
# 3  341.500430
# 4  244.902648
#
# [5 rows x 134 columns]

# %%
import pandas as pd

moradores = pd.read_csv("data/moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")

colunas = ["morador_id", "localidade", "idade_calculada", "id_genero", "escolaridade", "renda_ind", "peso_mor"]
print(moradores[colunas])
# Out:
# /tmp/xpython_42/1512070687.py:3: DtypeWarning: Columns (0: E03_1_1, 1: E03_2_1) have mixed types. Specify dtype option on import or set low_memory=False.
#   moradores = pd.read_csv("data/moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
#       morador_id  localidade  idade_calculada  id_genero  escolaridade  \
# 0        00001-1        5330               49          1             5
# 1        00002-1        5320               35          1             7
# 2        00002-2        5320               41          1             7
# 3        00002-3        5320                5      99999             1
# 4        00002-4        5320                3      99999             1
# ...          ...         ...              ...        ...           ...
# 69537    24844-2        5319               11      99999             2
# 69538    24844-3        5319                7      99999             2
# 69539    24844-4        5319                7      99999             2
# 69540    24845-1        5249               97          1             8
# 69541    24845-2        5249               51          1             8
#
#        renda_ind    peso_mor
# 0              0   78.620213
# 1          99999  148.818895
# 2          99999  212.895183
# 3              0  341.500430
# 4              0  244.902648
# ...          ...         ...
# 69537          0   14.546175
# 69538          0   13.599044
# 69539          0   15.464007
# 69540       1420   10.617782
# 69541       1420    9.421413
#
# [69542 rows x 7 columns]

# %%
import pandas as pd

domicilios = pd.read_excel("domicilios_parcial.xlsx")

for _, linha in domicilios.iterrows():
    print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 domicilios = pd.read_excel("domicilios_parcial.xlsx")
#       5 for _, linha in domicilios.iterrows():
#       6     print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File /lib/python3.13/site-packages/pandas/io/common.py:939, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#    (...)    935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
# --> 939         handle = open(handle, ioargs.mode)
#     940     handles.append(handle)
#     942 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 44] No such file or directory: 'domicilios_parcial.xlsx'

# %%
import pandas as pd

domicilios = pd.read_excel("data/domicilios.xlsx")

for _, linha in domicilios.iterrows():
    print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /lib/python3.13/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 domicilios = pd.read_excel("data/domicilios.xlsx")
#       5 for _, linha in domicilios.iterrows():
#       6     print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:1621, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1618 self.engine = engine
#    1619 self.storage_options = storage_options
# -> 1621 self._reader = self._engines[engine](
#    1622     self._io,
#    1623     storage_options=storage_options,
#    1624     engine_kwargs=engine_kwargs,
#    1625 )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_openpyxl.py:559, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 @doc(storage_options=_shared_docs["storage_options"])
#     542 def __init__(
#     543     self,
#    (...)    546     engine_kwargs: dict | None = None,
#     547 ) -> None:
#     548     """
#     549     Reader using openpyxl engine.
#     550
#    (...)    557         Arbitrary keyword arguments passed to excel engine.
#     558     """
# --> 559     import_optional_dependency("openpyxl")
#     560     super().__init__(
#     561         filepath_or_buffer,
#     562         storage_options=storage_options,
#     563         engine_kwargs=engine_kwargs,
#     564     )
#
# File /lib/python3.13/site-packages/pandas/compat/_optional.py:161, in import_optional_dependency(name, extra, min_version, errors)
#     159 except ImportError as err:
#     160     if errors == "raise":
# --> 161         raise ImportError(msg) from err
#     162     return None
#     164 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: `Import openpyxl` failed.  Use pip or conda to install the openpyxl package.

# %%
# !pip install openpyxl
# Out:
# mambajs 0.21.1
#
# Process pip requirements ...
#
# Successfully installed openpyxl-3.1.5 et-xmlfile-2.0.0

# %%
import pandas as pd

domicilios = pd.read_excel("domicilios_parcial.xlsx")

for _, linha in domicilios.iterrows():
    print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 import pandas as pd
# ----> 3 domicilios = pd.read_excel("domicilios_parcial.xlsx")
#       5 for _, linha in domicilios.iterrows():
#       6     print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:1604, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1601         ext = "xls"
#    1603 if ext is None:
# -> 1604     ext = inspect_excel_format(
#    1605         content_or_path=path_or_buffer, storage_options=storage_options
#    1606     )
#    1607     if ext is None:
#    1608         raise ValueError(
#    1609             "Excel file format cannot be determined, you must specify "
#    1610             "an engine manually."
#    1611         )
#
# File /lib/python3.13/site-packages/pandas/io/excel/_base.py:1452, in inspect_excel_format(content_or_path, storage_options)
#    1417 def inspect_excel_format(
#    1418     content_or_path: FilePath | ReadBuffer[bytes],
#    1419     storage_options: StorageOptions | None = None,
#    1420 ) -> str | None:
#    1421     """
#    1422     Inspect the path or content of an excel file and get its format.
#    1423
#    (...)   1450         If resulting stream does not have an XLS signature and is not a valid zipfile.
#    1451     """
# -> 1452     with get_handle(
#    1453         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1454     ) as handle:
#    1455         stream = handle.handle
#    1456         stream.seek(0)
#
# File /lib/python3.13/site-packages/pandas/io/common.py:939, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#    (...)    935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
# --> 939         handle = open(handle, ioargs.mode)
#     940     handles.append(handle)
#     942 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 44] No such file or directory: 'domicilios_parcial.xlsx'

# %%
# !mamba install pandas
# Out:
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.5905999999046325 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.3    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.2   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge
